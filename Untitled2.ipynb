# %% [markdown]
# <a href="https://colab.research.google.com/github/lee-eunbyul/-1/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 자율주행
# ## 뉴로 R2
# 1. 탄생 배경
# * 무인 배송 서비스를 실시하기 위해 만들어짐
# 2. 뉴로 R2의 특징
# * 좌석, 운전대, 페달, 백미러 같은 장치가 없음
# * 미국에서 이러한 장치가 없음에도 예외적으로 승인을 받은 자율주행차
# *주행 및 주변 환경에 대한 정보를 캡처해 지속적으로 자율주행 시스템을 개선할 수 있는 머신러닝 기능이 강화되어 데이터가 기록됨
# 3. 뉴로R2의 장단점
# * 장점: 무인으로 배송을 하기 때문에 접촉을 최소화 할 수 있어 바이러스같은 질병으로부터 안전, 인건비 절약에 큰 도움이 됨
# * 단점: 충돌사고 같은 일이 벌어질 수 있기때문에 아직까지는 많은 관리가 필요함
# 4. 뉴로 R2의 앞으로의 계획
# * 미국 휴스턴 지역에서 피자와 식료품 등을 배송할 예정
# * 격리시설같은 곳으로 의료물품을 배송할 예정
#
#  # 음성
#  ## Siri
#  1. 탄생 배경
#  * SRI 국제인공지능센터에서 개발한 프로젝트였음.
#  * 2010년에 애플이 SRI를 인수, 2011년 10월 아이폰4S와 함께 소개 됨.
#  2. Siri의 특징
#  * 디지털 신호처리를 통해 인간의 음성을 더욱 정확하게 들을 수 있음
#  * 동적 시간 워핑 알고리즘을 활용해 데이터간의 유사성을 판별할 수 있음.
#  * tagging을 통해 사용자가 무엇을 원하는지 카테고리별로 분류해 처리해줌
#  3. Siri의 장단점
#  * 장점: 전화나 문자를 음성인식만으로 해결 할 수 있음, 일상적인 작업을 더 빠르고 쉽게 해결해 줄 수 있음, 모든 지식에 대해 다 알고 있음.
#  * 단점: 오프라인 상태에서는 사용할 수 없음. 시리에게 말을 할때에는 천천히 말해줘야 알아들을 수 있음.
#  # 이미지
#  ## PAIGE
#  1. 탄생 배경
#  * NC SOFT사의 야구 정보 앱 PAIGE는 나만의 야구 페이지를 만드는 것처럼 내가 관심있는 구단의 소식, 퀴즈, 야구 친구와 채팅 등 야구를 더욱 쉽게 접할 수 있게하기 위해 만들어짐.
#  2. PAIGE의 특징
#  * 이미지 인식 기술을 통해 야구 중계 동영상의 정보를 태깅하고 이 기록된 정보를 검색키워드를 통해 하이라이트의 구간의 시작과 끝 지점을 찾음
#  * 장면 전환 검출 기술과 장면 분류를 이용해 하이라이트 분할 구간을 정교화 함
#  ## 어도비 센세이
#  1. 어도비 센세이의 특징
#  * 어도비의 캐릭터 애니메이터는 실시간으로 애니메이션 캐릭터를 만들 수 있음
#  * 이미지를 불러오면 태그를 자동으로 추출하고 관련된 이미지들을 보여 줌
#  * 얼굴 인식 기술을 활용해 동작 기반 애니메이션을 실시간으로 재현해낼 수 있음
#  # 언어
#  ## 구글 번역
#  1. 구글 번역의 특징
#  * 다언어 통역 기계번역 서비스
#  * 2006년 4월에 선보였고 UN,유럽의회 구술 기록을 사용해 만들었음
#  * 언어를 직접 번역 하지않고 텍스트를 영어로 우선 번역 한다음 대상언어로 변환함
#  * 구글 신경기계번역 서비스를 만들어 한번에 전체 문장을 번역할 수 있어 정확도를 높임
#  2. 단점
#  * 구글 신경기계번역 서비스를 만들어 정확도를 높였지만 아직까지 문장이 매끄럽게 번역되지 않음
#  * 오프라인에서도 사용할 수 있게 되었지만 인터넷연결을 사용했을때와 비교하면 정확도가 떨어짐
#  ## 네이버 파파고
#  1. 파파고의 특징
#  * WSD화면을 이용해 중의적 단어처리 문제를 해결함
#  * NAVER LABS에서 자체개발한 인공신경망 기반 번역 서비스
#  * 1:1 대화모드 ,이미지 번역 등 다양한 기능이 많음
#  * 네트워크 없이도 사용가능한 글로벌 회화, 즐겨찾기에 사용자가 번역한 문장을 추가할 수 있음
#  * PUSH-TO-TALK 라는 기능을 이용해 소음이 많은 상황에서도 음성 인식이 가능함
#  2. 단점
#  * WSD화면을 이용해 중의적 단어를 처리 할 수 있지만 아직까지는 완벽하게 처리 할 수 없음
#  * 특정 외국어를 번역하거나 외국어와 외국어를 합친 단어를 번역하면 번역이 잘 되지않아 불편함
